# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import *
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("California_Houses.csv")

# %%
df.head(1000)
# Out:
#      Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0              452600.0         8.3252          41        880           129
# 1              358500.0         8.3014          21       7099          1106
# 2              352100.0         7.2574          52       1467           190
# 3              341300.0         5.6431          52       1274           235
# 4              342200.0         3.8462          52       1627           280
# ..                  ...            ...         ...        ...           ...
# 995            192400.0         4.8624          11      12070          2220
# 996            418800.0         9.1531          25        494            81
# 997            216800.0         4.7361          22       5533           943
# 998            215500.0         5.4324          17       3956           639
# 999            227700.0         4.9375          12       1906           351
#
#      Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0           322         126     37.88    -122.23        9263.040773
# 1          2401        1138     37.86    -122.22       10225.733072
# 2           496         177     37.85    -122.24        8259.085109
# 3           558         219     37.85    -122.25        7768.086571
# 4           565         259     37.85    -122.25        7768.086571
# ..          ...         ...       ...        ...                ...
# 995        5826        2125     37.71    -121.75       36153.866009
# 996         254          85     37.74    -121.77       33031.749658
# 997        2474         910     37.70    -121.80       32560.957256
# 998        2222         662     37.69    -121.80       32301.734489
# 999         802         319     37.69    -121.82       30586.194871
#
#      Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# 0     556529.158342         735501.806984         67432.517001
# 1     554279.850069         733236.884360         65049.908574
# 2     554610.717069         733525.682937         64867.289833
# 3     555194.266086         734095.290744         65287.138412
# 4     555194.266086         734095.290744         65287.138412
# ..              ...                   ...                  ...
# 995   514897.043562         694185.562163         43513.047534
# 996   518598.446233         697894.584524         46270.099629
# 997   516809.796810         696048.481745         41354.831656
# 998   515950.596782         695179.986203         40265.702643
# 999   517070.552130         696281.114760         39943.587587
#
#      Distance_to_SanFrancisco
# 0                21250.213767
# 1                20880.600400
# 2                18811.487450
# 3                18031.047568
# 4                18031.047568
# ..                        ...
# 995              60327.280077
# 996              58258.658680
# 997              56119.751279
# 998              56297.167678
# 999              54563.476285
#
# [1000 rows x 14 columns]

# %%
y = df['Median_House_Value']
x = df[['Median_Income',	'Median_Age',	'Tot_Rooms'	,'Tot_Bedrooms',	'Population',	'Households',	'Latitude',	'Longitude',	'Distance_to_coast',	'Distance_to_LA',	'Distance_to_SanDiego',	'Distance_to_SanJose',	'Distance_to_SanFrancisco']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100, shuffle = True)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = 100, shuffle = True)

# %%
# np.array(x_train).shape
# np.array(x_test).shape
# np.array(x_val).shape

# np.array(y_train).shape
# np.array(y_test).shape
# np.array(y_val).shape

# %%
# x_train = np.array(x_train).reshape(-1, 1)
# x_test = np.array(x_test).reshape(-1, 1)
# x_val = np.array(x_val).reshape(-1, 1)


y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)
y_val = np.array(y_val).reshape(-1, 1)

# %%
# np.array(y_train).shape
np.array(y_test).shape
# np.array(y_val).shape
# Out:
# (3096, 1)

# %%
scaler = StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_val=scaler.transform(x_val)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict = lr.predict(x_train)

# %%
y_train = y_train.flatten()
y_train_predict = y_train_predict.flatten()

plt.figure(figsize=(8, 6))
plt.scatter(y_train, y_train_predict, alpha=0.5)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
mse = mean_squared_error(y_train, y_train_predict)
mae = mean_absolute_error(y_train, y_train_predict)
print(mse)
print(mae)
# Out:
# 4814917621.605248
# 50307.568737046466

# %%
y_val_prediction = lr.predict(x_val)

# %%
np.array(y_val).shape
# Out:
# (3096, 1)

# %%
np.array(y_val_prediction).shape
# Out:
# (3096, 1)

# %%
y_val = y_val.flatten()
y_val_prediction = y_val_prediction.flatten()

# Scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_val, y_val_prediction, alpha=0.5)
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
y_test_predictions=lr.predict(x_test)

# %%
y_test = y_test.flatten()
y_test_prediction = y_test_predictions.flatten()

# Scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_prediction, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
mse_test = mean_squared_error(y_test, y_test_predictions)
mae_test = mean_absolute_error(y_test, y_test_predictions)
print(mse)
print(mae)
# Out:
# 4814917621.605248
# 50307.568737046466
